# %%
# %pylab inline
import numpy as np
import pandas as pd
import scipy.stats as stats
import random
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
z = pd.read_csv('./zscore_550cells_min9perLineage.txt', index_col=0, sep='\t')
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 550 entries, ACH-000004 to ACH-001957
# Columns: 17407 entries, A1BG to ZZZ3
# dtypes: float64(17407)
# memory usage: 73.0+ MB

# %%
cc_diff_actual =pd.read_table('delta-cc-aml-minus-exBlood.txt', sep=',', index_col=0)
cc_diff_actual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17407 entries, A1BG to ZZZ3
# Columns: 17407 entries, A1BG to ZZZ3
# dtypes: float64(17407)
# memory usage: 2.3+ GB

# %%
cc_diff_counter = pd.DataFrame(index=cc_diff_actual.index, columns=cc_diff_actual.index, data=0)
cc_diff_counter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17407 entries, A1BG to ZZZ3
# Columns: 17407 entries, A1BG to ZZZ3
# dtypes: int64(17407)
# memory usage: 2.3+ GB

# %%
subset = random.sample( list(z.index), 15)
subset
# Out:
# ['ACH-001303',
#  'ACH-000433',
#  'ACH-000986',
#  'ACH-000211',
#  'ACH-000510',
#  'ACH-000767',
#  'ACH-000576',
#  'ACH-001075',
#  'ACH-000331',
#  'ACH-000490',
#  'ACH-000148',
#  'ACH-001332',
#  'ACH-000824',
#  'ACH-000152',
#  'ACH-000415']

# %%
remaining = np.setdiff1d( list(z.index), subset )
remaining
# Out:
# array(['ACH-000004', 'ACH-000007', 'ACH-000009', 'ACH-000011',
#        'ACH-000012', 'ACH-000013', 'ACH-000014', 'ACH-000015',
#        'ACH-000017', 'ACH-000018', 'ACH-000019', 'ACH-000021',
#        'ACH-000022', 'ACH-000025', 'ACH-000028', 'ACH-000030',
#        'ACH-000035', 'ACH-000036', 'ACH-000037', 'ACH-000039',
#        'ACH-000040', 'ACH-000041', 'ACH-000042', 'ACH-000045',
#        'ACH-000047', 'ACH-000052', 'ACH-000053', 'ACH-000054',
#        'ACH-000055', 'ACH-000060', 'ACH-000067', 'ACH-000070',
#        'ACH-000075', 'ACH-000078', 'ACH-000082', 'ACH-000085',
#        'ACH-000086', 'ACH-000087', 'ACH-000092', 'ACH-000095',
#        'ACH-000097', 'ACH-000098', 'ACH-000099', 'ACH-000108',
#        'ACH-000113', 'ACH-000116', 'ACH-000118', 'ACH-000120',
#        'ACH-000123', 'ACH-000127', 'ACH-000128', 'ACH-000132',
#        'ACH-000137', 'ACH-000138', 'ACH-000142', 'ACH-000143',
#        'ACH-000146', 'ACH-000150', 'ACH-000153', 'ACH-000159',
# ...

# %%
cc_diff_sample = z.loc[subset].corr() - z.loc[remaining].corr()
cc_diff_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17407 entries, A1BG to ZZZ3
# Columns: 17407 entries, A1BG to ZZZ3
# dtypes: float64(17407)
# memory usage: 2.3+ GB

# %%
cc_diff_counter.iloc[:5,:5]
# Out:
#          A1BG  A1CF  A2M  A2ML1  A3GALT2
# A1BG        0     0    0      0        0
# A1CF        0     0    0      0        0
# A2M         0     0    0      0        0
# A2ML1       0     0    0      0        0
# A3GALT2     0     0    0      0        0

# %%
cc_diff_sample.iloc[:5,:5]
# Out:
#              A1BG      A1CF       A2M     A2ML1   A3GALT2
# A1BG     0.000000 -0.076458 -0.135747  0.132426 -0.153260
# A1CF    -0.076458  0.000000 -0.285201  0.370683 -0.108456
# A2M     -0.135747 -0.285201  0.000000 -0.216341  0.249113
# A2ML1    0.132426  0.370683 -0.216341  0.000000 -0.062105
# A3GALT2 -0.153260 -0.108456  0.249113 -0.062105  0.000000

# %%
cc_diff_actual.iloc[:5,:5]
# Out:
#           A1BG   A1CF    A2M  A2ML1  A3GALT2
# A1BG     0.000  0.243  0.629 -0.521    0.250
# A1CF     0.243  0.000  0.553  0.298    0.652
# A2M      0.629  0.553  0.000 -0.091    0.289
# A2ML1   -0.521  0.298 -0.091  0.000    0.224
# A3GALT2  0.250  0.652  0.289  0.224    0.000

# %%
cc_diff_sample > cc_diff_actual
# Out:
#           A1BG   A1CF    A2M  A2ML1  A3GALT2  A4GALT  A4GNT   AAAS   AACS  \
# A1BG     False  False  False   True    False    True   True  False   True
# A1CF     False  False  False   True    False    True   True   True   True
# A2M      False  False  False  False    False    True   True  False   True
# A2ML1     True   True  False  False    False   False   True   True   True
# A3GALT2  False  False  False  False    False    True   True   True   True
# ...        ...    ...    ...    ...      ...     ...    ...    ...    ...
# ZYG11A    True   True  False  False    False   False   True   True  False
# ZYG11B    True  False  False  False    False    True   True   True  False
# ZYX       True   True  False   True    False   False  False   True  False
# ZZEF1    False  False  False   True    False   False   True   True   True
# ZZZ3     False   True  False   True     True    True  False   True   True
#
#          AADAC  ...   ZUP1   ZW10  ZWILCH  ZWINT   ZXDC  ZYG11A  ZYG11B  \
# ...

# %%
#miss = where( cc_diff_sample.index != cc_diff_actual.index )[0]
miss = where( z.columns != cc_diff_sample.index )[0]
miss
# Out:
# array([], dtype=int64)

# %%
cc_diff_sample.index[miss]

# %%
cc_diff_actual.index[miss]
